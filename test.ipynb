# %%
from predicter.predict import Deep_face_predict
import cv2
import matplotlib.pyplot as plt

# %%
import subprocess
import os

os.system(r'start D:/Study/AI/Project/Project_Ai_Pj1/PJ1/Person_image')
# Out:
# 0

# %%
image = cv2.imread("Face_image/Caltech_face/Nguyen Thuc Anh/a9c9200a1dffc6a19fee20.jpg")

# %%
plt.imshow(image)

# %%
def rotate_image(original_image, angle):

    # Get the height and width of the original image
    height, width = original_image.shape[:2]

    # Calculate the rotation matrix
    rotation_matrix = cv2.getRotationMatrix2D((width / 2, height / 2), angle, 1)

    # Apply the rotation to create a new image
    rotated_image = cv2.warpAffine(original_image, rotation_matrix, (width, height))

    return rotated_image

# %%
from imgaug import augmenters as iaa

augmentation = iaa.Sequential([
    # iaa.Fliplr(0.5),  # Horizontal flip with 50% probability
    iaa.Affine(rotate=(-15, 15)),  # Random rotation between -45 and 45 degrees
    # iaa.GaussianBlur(sigma=(0, 3.0)),  # Gaussian blur with varying sigma
    # iaa.AdditiveGaussianNoise(scale=(0, 0.1*255))  # Gaussian noise
])

def transform_face(face):
    list_face = []
    list_face.append(face)
    
    list_face.append(rotate_image(face, 10))
    
    list_face.append(rotate_image(face, -10))
    
    augmentation = iaa.Sequential([
    iaa.Fliplr(1),  # Random rotation between -45 and 45 degrees
    ])
    list_face.append(augmentation(image = face))
    
    return list_face

list_face = transform_face(image)
plt.imshow(list_face[2])

# %%
plt.imshow(rotate_image(image, -45))

# %%
tmp = Deep_face_predict(image)
# Out:
# WARNING: Representations for images in  Person_image  folder were previously stored in  representations_facenet.pkl . If you added new instances after this file creation, then please delete this file and call find function again. It will create it again.
# There are  34  representations found in  representations_facenet.pkl
# 1/1 [==============================] - 1s 1s/step
# find function lasts  3.968219518661499  seconds

# %%
tmp
# Out:
# 'Nguyen Thuc Anh'

# %%
import pickle
import numpy as np

f = open('Person_image/representations_facenet.pkl', 'rb')
f = pickle.load(f)

# %%
import tensorflow as tf

print("Phiên bản TensorFlow của bạn là:", tf.__version__)
# Out:
# 2023-09-12 11:00:54.671865: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-09-12 11:00:54.712187: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-09-12 11:00:54.713018: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-12 11:00:55.445564: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Phiên bản TensorFlow của bạn là: 2.13.0

# %%
f = np.array(f)
f
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 f = np.array(f)
#       2 f
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (29, 2) + inhomogeneous part.

# %%
for pcidev in $(lspci -D|grep 'VGA compatible controller: NVIDIA'|sed -e 's/[[:space:]].*//'); do echo 0 > /sys/bus/pci/devices/${pcidev}/numa_node; done
# Out:
#   Cell In[4], line 1
#     for a in /sys/bus/pci/devices/*; do echo 0 | sudo tee -a $a/numa_node; done
#              ^
# SyntaxError: invalid syntax
